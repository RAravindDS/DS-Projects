# %%
import pandas as pd
import numpy as np

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
password = pd.read_csv('data.csv', ',', error_bad_lines = False )
# Out:
# b'Skipping line 2810: expected 2 fields, saw 5\nSkipping line 4641: expected 2 fields, saw 5\nSkipping line 7171: expected 2 fields, saw 5\nSkipping line 11220: expected 2 fields, saw 5\nSkipping line 13809: expected 2 fields, saw 5\nSkipping line 14132: expected 2 fields, saw 5\nSkipping line 14293: expected 2 fields, saw 5\nSkipping line 14865: expected 2 fields, saw 5\nSkipping line 17419: expected 2 fields, saw 5\nSkipping line 22801: expected 2 fields, saw 5\nSkipping line 25001: expected 2 fields, saw 5\nSkipping line 26603: expected 2 fields, saw 5\nSkipping line 26742: expected 2 fields, saw 5\nSkipping line 29702: expected 2 fields, saw 5\nSkipping line 32767: expected 2 fields, saw 5\nSkipping line 32878: expected 2 fields, saw 5\nSkipping line 35643: expected 2 fields, saw 5\nSkipping line 36550: expected 2 fields, saw 5\nSkipping line 38732: expected 2 fields, saw 5\nSkipping line 40567: expected 2 fields, saw 5\nSkipping line 40576: expected 2 fields, saw 5\nSkipping lin
# ...

# %%
password.head()
# Out:
#       password  strength
# 0     kzde5577         1
# 1     kino3434         1
# 2    visi7k1yr         1
# 3     megzy123         1
# 4  lamborghin1         1

# %%
password.shape
# Out:
# (669640, 2)

# %%
password.isnull().sum()
# Out:
# password    1
# strength    0
# dtype: int64

# %%
password[password['password'].isnull()] # checking the null index
# Out:
#        password  strength
# 367579      NaN         0

# %%
password.dropna(inplace = True)

# %%
tup = np.array(password)

# %%
tup
# Out:
# array([['kzde5577', 1],
#        ['kino3434', 1],
#        ['visi7k1yr', 1],
#        ...,
#        ['184520socram', 1],
#        ['marken22a', 1],
#        ['fxx4pw4g', 1]], dtype=object)

# %%
# In here we have the data like in order, so we need to reshuffle the order.

# %%
import random 
random.shuffle(tup)
y = [i[1] for i in tup]
X = [ i[0] for i in tup]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
# def sepa(inputs):
#     cha = []
#     for i in inputs:
#         cha.append(i)
#     return cha

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vec = TfidfVectorizer()

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# cv = CountVectorizer()
# sc = cv.fit(X)

# %%
X = vec.fit_transform(X)

# %%
path = 'C:/Users/aravi/Downloads/Krish_Naik_live_projects/password_strength_Project2/Deploy/xgbtranss.pkl'
import pickle
with  open(path, 'wb') as file:
    pickle.dump(vec, file)

# %%
X.shape
# Out:
# (669639, 337191)

# %%
vec.vocabulary_
# Out:
# {'kzde5577': 178129,
#  'kino3434': 171080,
#  'visi7k1yr': 300531,
#  'lamborghin1': 179571,
#  'avyq1lde4mgazfnt': 62742,
#  'v1118714': 295496,
#  'wut9izze0oq7pkne': 313500,
#  'as326159': 60071,
#  'idofo673': 141105,
#  '52558000aaa': 30991,
#  'sbl571017': 262906,
#  'jytifok873': 161112,
#  'u6c8vhow': 289375,
#  'asv5o9yu': 61429,
#  'universe2908': 292698,
#  'trabajonet9': 286310,
#  'faranumar91': 111767,
#  'intel1': 144724,
#  'exitos2009': 109780,
#  'schalke04': 263155,
#  'prisonbreak1': 241566,
#  'phyquediynq8vmhb': 236728,
#  'alimagik1': 53981,
#  '6975038lp': 35141,
#  'gaymaids1': 120646,
#  'yk530mg8': 324442,
#  'jerusalem393': 151879,
#  'tywm72uneex8q8y': 288882,
#  'lsdlsd1': 186742,
#  'yqugu927': 326777,
#  'il0vey0u': 142722,
#  'bozoxik602': 73615,
#  'calcifer32': 77687,
#  'kunyukbabi69': 176898,
#  'k9b8cz6aj2': 162266,
#  'khmer100': 169528,
#  '03278': 1700,
#  'mnb': 205853,
#  'fk9qi21m': 114569,
#  'j09000': 148189,
#  'd04m11': 89516,
# ...

# %%
X.shape
# Out:
# (669639, 337191)

# %%
# from sklearn.linear_model import LogisticRegression

# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 43)
# logr = LogisticRegression(penalty='l2', multi_class= 'ovr')
# logr.fit(X_train, y_train) # we are chaning binary logistic regression to multi class regression

# %%
# print("Trainning Score:", logr.score(X_train, y_train))

# %%
# logr1 = LogisticRegression(penalty='l2', multi_class= 'multinomial', solver = 'newton-cg')
# logr1.fit(X_train, y_train)
# print("Trainning Score:", logr.score(X_train, y_train))

# %%
# # te = np.array(['8iuiou#@&3'])
# tes = vec.transform(te)

# %%
# pred = logr.predict(tes)
# print(pred)

# %% [markdown]
# # XGB

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 43)

# %%
import xgboost as xgb
xgg = xgb.XGBClassifier()
xgg.fit(X_train, y_train)
print("Score:",xgg.score(X_test, y_test))
# Out:
# [14:25:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Score: 0.7441311749596798

# %%
te = np.array(['abc@&*df;lk!#@'])
tes = vec.transform(te)
pred = xgg.predict(tes)
print(pred)
# Out:
# [1]

# %% [markdown]
# # NB

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train, y_train)
print(nb.score(X_test, y_test))

# %%
te = np.array(['abc@&*df;lk!#@'])
tes = vec.transform(te)
pred = nb.predict(tes)
print(pred)

# %%
path = 'C:/Users/aravi/Downloads/Krish_Naik_live_projects/password_strength_Project2/Deploy/xgb.pkl'
import pickle
with  open(path, 'wb') as file:
    pickle.dump(xgg, file)

# %%
with open(path, 'rb') as file:
    model = pickle.load(file)

# %%
te = np.array(['abc@&*df;lk!#@'])
tes = vec.transform(te)
pred = model.predict(tes)
print(pred)
# Out:
# [1]

# %%
path = 'C:/Users/aravi/Downloads/Krish_Naik_live_projects/password_strength_Project2/Deploy/xgbtranss.pkl'
with open(path, 'rb') as file:
    model = pickle.load(file)

# %%
c = model.transform(['arandn'])

# %%
c

# %%
pred = xgg.predict(c)
print(pred)
